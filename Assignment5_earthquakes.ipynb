# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
from pandas_profiling import ProfileReport

# %%
df = pd.read_csv('earthquakes')
df.head(10)
# Out:
#                        time   latitude   longitude      depth   mag magType  \
# 0  2021-11-25T02:22:39.990Z  33.665833 -116.775667  14.430000  0.98      ml
# 1  2021-11-25T02:18:47.640Z  38.564999 -119.455498   2.500000  2.11      md
# 2  2021-11-25T02:16:05.228Z  36.368938  -97.340614   2.847088  2.34      ml
# 3  2021-11-25T02:04:54.180Z  19.188499 -155.487167  30.600000  1.72      ml
# 4  2021-11-25T01:57:27.020Z  33.490500 -116.785167   3.350000  1.38      ml
# 5  2021-11-25T01:54:48.604Z  36.380783  -97.350258   2.133806  1.72      ml
# 6  2021-11-25T01:53:34.360Z  62.053400 -148.456900  13.500000  2.80      ml
# 7  2021-11-25T01:47:30.130Z  38.822666 -122.788002   1.720000  0.84      md
# 8  2021-11-25T01:37:04.277Z  35.091686  -95.408218   1.431819  1.92      ml
# 9  2021-11-25T01:27:04.120Z  60.771800 -150.586700  22.800000  1.40      ml
#
#     nst         gap      dmin       rms  ...                   updated  \
# ...

# %%
df.describe()
# Out:
#           latitude    longitude        depth          mag          nst  \
# count  9359.000000  9359.000000  9359.000000  9358.000000  6789.000000
# mean     36.740581  -112.734524    22.194510     1.651303    20.993372
# std      19.523699    62.346470    52.144866     1.207933    15.565365
# min     -62.624300  -179.967300    -7.300000    -1.210000     0.000000
# 25%      33.499500  -149.830850     3.080649     0.850000    10.000000
# 50%      38.193700  -120.625000     8.100000     1.450000    16.000000
# 75%      44.997583  -115.606917    18.110000     2.090000    28.000000
# max      85.862200   179.941000   632.600000     6.600000   221.000000
#
#                gap         dmin          rms  horizontalError   depthError  \
# count  7808.000000  6546.000000  9358.000000      6927.000000  9358.000000
# mean    116.806289     0.659137     0.268708         1.645812     2.200064
# std      58.877607     2.363070     0.284088         2.967873     5.195252
# ...

# %%
profile.to_file('earthquakes.html')

# %%
df = pd.read_csv('earthquakes')
print(df.head(5))

# %%
print(df.columns)

# %%
print(df.iloc[1:4])

# %%
print(df.iloc[2,1])

# %%
df.sort_values

# %%
# %matplotlib inline
fig, ax=plt.subplots()
df.plot(kind='scatter', y='latitude', x='longitude', ax=ax)
# Out:
# <AxesSubplot:xlabel='longitude', ylabel='latitude'>

# %%
print(df)
# Out:
#                           time   latitude   longitude       depth   mag  \
# 0     2021-11-25T02:22:39.990Z  33.665833 -116.775667   14.430000  0.98
# 1     2021-11-25T02:18:47.640Z  38.564999 -119.455498    2.500000  2.11
# 2     2021-11-25T02:16:05.228Z  36.368938  -97.340614    2.847088  2.34
# 3     2021-11-25T02:04:54.180Z  19.188499 -155.487167   30.600000  1.72
# 4     2021-11-25T01:57:27.020Z  33.490500 -116.785167    3.350000  1.38
# ...                        ...        ...         ...         ...   ...
# 9354  2021-10-26T03:00:34.922Z  62.869200 -151.236000  108.000000  1.40
# 9355  2021-10-26T02:56:37.950Z  39.431000 -110.326833   -1.220000  1.39
# 9356  2021-10-26T02:52:34.940Z  47.563167 -114.135167    5.210000 -0.13
# 9357  2021-10-26T02:46:44.410Z  53.858833 -166.763000    7.030000  0.00
# 9358  2021-10-26T02:39:32.600Z  38.423833 -122.626833    5.210000  1.97
#
#      magType   nst         gap      dmin       rms  ...  \
# ...

# %%
df['location']=df['place'].str.split(', ', expand=True)[1]
df['location'].value_counts()
# Out:
# CA                3216
# Alaska            1932
# Hawaii             897
# Nevada             477
# Utah               291
#                   ...
# United Kingdom       1
# Kyrgyzstan           1
# Ohio                 1
# Azerbaijan           1
# Ethiopia             1
# Name: location, Length: 96, dtype: int64

# %%
df_location=pd.DataFrame(df['location'].value_counts())

# %%
df_location
# Out:
#              index  location
# 0               CA      3216
# 1           Alaska      1932
# 2           Hawaii       897
# 3           Nevada       477
# 4             Utah       291
# ..             ...       ...
# 91  United Kingdom         1
# 92      Kyrgyzstan         1
# 93            Ohio         1
# 94      Azerbaijan         1
# 95        Ethiopia         1
#
# [96 rows x 2 columns]

# %%
df_location.reset_index(inplace=True)

# %%
df_location[df_location['location']>20].plot.bar(x='index', y='location')
# Out:
# <AxesSubplot:xlabel='index'>
